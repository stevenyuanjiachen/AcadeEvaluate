# %% [markdown]
# 学术评价网站
# 输入一篇文章后，列出所有引用这篇文章的文献，以及这些文献评价该文章的话。
# 使用大模型总结文献对该文章的评价。

# %%
import os
import requests
import re
import pandas as pd
from typing import Generator, Union
S2_API_KEY = os.environ.get('S2_API_KEY', '')

# %% [markdown]
# # Transfer PaperID
# 如何转换成兼容的格式

# %%
def print_papers(papers):
    for idx, paper in enumerate(papers):
        print(f"{idx}  {paper['title']} || {','.join(author['name'] for author in paper['authors'])} || {paper['url']}")

def find_paper_by_title(query=None, result_limit = 10):
    papers = None
    while not papers:
        if not query:
            query = input('Find papers about what: ')
        if not query:
            continue

        rsp = requests.get('https://api.semanticscholar.org/graph/v1/paper/search',
                           headers={'X-API-KEY': S2_API_KEY},
                           params={'query': query, 'limit': result_limit, 'fields': 'authors,title,url'})
        rsp.raise_for_status()
        results = rsp.json()
        total = results["total"]
        if not total:
            print('No matches found. Please try another query.')
            continue

        print(f'Found {total} results. Showing up to {result_limit}.')
        papers = results['data']
        print_papers(papers)

    selection = ''
    while not re.fullmatch('\\d+', selection):
        selection = input('Select a paper # to base recommendations on: ')
    return results['data'][int(selection)]

find_paper_by_title()
# Out:
# Found 2 results. Showing up to 10.
# 0  Evaluating GPT and BERT models for protein–protein interaction identification in biomedical text || Hasin Rehana,Nur Bengisu Çam,Mert Basmaci,Jie Zheng,Christianah Jemiyo,Yongqun He,Arzucan Özgür,J. Hur || https://www.semanticscholar.org/paper/50a3f0dd12114fb2ca90a5511a6325524c3f6013
# 1  Evaluation of GPT and BERT-based models on identifying proteinprotein interactions in biomedical text || Hasin Rehana,Nur Bengisu Çam,Mert Basmaci,Y. He,Arzucan Özgür,J. Hur || https://www.semanticscholar.org/paper/1ad9a295ea841599383e5ae3e88381438d4a7db3
# {'paperId': '50a3f0dd12114fb2ca90a5511a6325524c3f6013',
#  'url': 'https://www.semanticscholar.org/paper/50a3f0dd12114fb2ca90a5511a6325524c3f6013',
#  'title': 'Evaluating GPT and BERT models for protein–protein interaction identification in biomedical text',
#  'authors': [{'authorId': '35668704', 'name': 'Hasin Rehana'},
#   {'authorId': '2214609905', 'name': 'Nur Bengisu Çam'},
#   {'authorId': '2180883959', 'name': 'Mert Basmaci'},
#   {'authorId': '2315466736', 'name': 'Jie Zheng'},
#   {'authorId': '2321307305', 'name': 'Christianah Jemiyo'},
#   {'authorId': '2249526854', 'name': 'Yongqun He'},
#   {'authorId': '2113900183', 'name': 'Arzucan Özgür'},
#   {'authorId': '1747690', 'name': 'J. Hur'}]}

# %% [markdown]
# # Get Citations
# 用来返回引用

# %%
def get_citation_edges(**req_kwargs):
    """This helps with API endpoints that involve paging."""
    page_size = 1000
    offset = 0
    while True:
        req_kwargs.setdefault('params', dict())
        req_kwargs['params']['limit'] = page_size
        req_kwargs['params']['offset'] = offset
        rsp = requests.get(**req_kwargs)
        rsp.raise_for_status()

        page = rsp.json()["data"]
        for element in page:
            yield element

        if len(page) < page_size:
            break  # no more pages
        offset += page_size

def get_paper(paper_id):
    rsp = requests.get(f'https://api.semanticscholar.org/graph/v1/paper/{paper_id}',
                       headers={'X-API-KEY': S2_API_KEY},
                       params={'fields': 'title,authors'})
    rsp.raise_for_status()
    return rsp.json()


def get_citations(paper_id):
    edges = get_citation_edges(url=f'https://api.semanticscholar.org/graph/v1/paper/{paper_id}/citations',
                               headers={'X-API-KEY': S2_API_KEY},
                               params={'fields': 'title,authors,isOpenAccess,openAccessPdf'})
    return list(edge['citingPaper'] for edge in edges)

# %%
print(get_paper('DOI:10.18653/v1/N18-3011'))
# Out:
# {'paperId': '649def34f8be52c8b66281af98ae884c09aef38b', 'title': 'Construction of the Literature Graph in Semantic Scholar', 'authors': [{'authorId': '145585097', 'name': 'Bridger Waleed Ammar'}, {'authorId': '3458736', 'name': 'Dirk Groeneveld'}, {'authorId': '1857797', 'name': 'Chandra Bhagavatula'}, {'authorId': '46181066', 'name': 'Iz Beltagy'}, {'authorId': '46230609', 'name': 'Miles Crawford'}, {'authorId': '145612610', 'name': 'Doug Downey'}, {'authorId': '38092776', 'name': 'Jason Dunkelberger'}, {'authorId': '143718836', 'name': 'Ahmed Elgohary'}, {'authorId': '46411828', 'name': 'Sergey Feldman'}, {'authorId': '4480314', 'name': 'Vu A. Ha'}, {'authorId': '143967880', 'name': 'Rodney Michael Kinney'}, {'authorId': '41018147', 'name': 'Sebastian Kohlmeier'}, {'authorId': '46258841', 'name': 'Kyle Lo'}, {'authorId': '144240185', 'name': 'Tyler C. Murray'}, {'authorId': '46256862', 'name': 'Hsu-Han Ooi'}, {'authorId': '39139825', 'name': 'Matthew E. Peters'}, {'authorId': '39561369', 'name': 'Joanna L. Power'}, {'authorId': '46181683', 'name': 'Sam Skjonsberg'}, {'authorId': '31860505', 'name': 'Lucy Lu Wang'}, {'authorId': '46212260', 'name': 'Christopher Wilhelm'}, {'authorId': '2112339497', 'name': 'Zheng Yuan'}, {'authorId': '15292561', 'name': 'Madeleine van Zuylen'}, {'authorId': '1741101', 'name': 'Oren Etzioni'}]}

# %%
citation1 = get_citations('DOI:10.18653/v1/N18-3011')
display(citation1)
citation_df = pd.DataFrame(citation1)
display(citation_df)
# Out:
# [{'paperId': 'db4e8d662dbe80f3ddf78e69b1c1053500894d25',
#   'title': 'A Database of Stress-Strain Properties Auto-generated from the Scientific Literature using ChemDataExtractor',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2193266278', 'name': 'Pankaj Kumar'},
#    {'authorId': '2331845884', 'name': 'Saurabh Kabra'},
#    {'authorId': '2164374024', 'name': 'Jacqueline M. Cole'}]},
#  {'paperId': '50a3f0dd12114fb2ca90a5511a6325524c3f6013',
#   'title': 'Evaluating GPT and BERT models for protein–protein interaction identification in biomedical text',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '35668704', 'name': 'Hasin Rehana'},
#    {'authorId': '2214609905', 'name': 'Nur Bengisu Çam'},
#    {'authorId': '2180883959', 'name': 'Mert Basmaci'},
#    {'authorId': '2315466736', 'name': 'Jie Zheng'},
#    {'authorId': '2321307305', 'name': 'Christianah Jemiyo'},
#    {'authorId': '2249526854', 'name': 'Yongqun He'},
#    {'authorId': '2113900183', 'name': 'Arzucan Özgür'},
#    {'authorId': '1747690', 'name': 'J. Hur'}]},
#  {'paperId': '5eafc35cedbb28b033009947ca73b40007b2b407',
#   'title': 'Paper Copilot: A Self-Evolving and Efficient LLM System for Personalized Academic Assistance',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2301577462', 'name': 'Guanyu Lin'},
#    {'authorId': '2300275413', 'name': 'Tao Feng'},
#    {'authorId': '2320307700', 'name': 'Pengrui Han'},
#    {'authorId': '2320318070', 'name': 'Ge Liu'},
#    {'authorId': '2261495159', 'name': 'Jiaxuan You'}]},
#  {'paperId': '4772df95a893061e0fedc9a09c56f95d8926fb9d',
#   'title': 'Temporal Graph Neural Network-Powered Paper Recommendation on Dynamic Citation Networks',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2284397773', 'name': 'Junhao Shen'},
#    {'authorId': '2317113659', 'name': 'Mohammad Ausaf Ali Haqqani'},
#    {'authorId': '2284602161', 'name': 'Beichen Hu'},
#    {'authorId': '2317093462', 'name': 'Cheng Huang'},
#    {'authorId': '2166234976', 'name': 'Xihao Xie'},
#    {'authorId': '2294376453', 'name': 'Tsengdar Lee'},
#    {'authorId': '2317130623', 'name': 'Jia Zhang'}]},
#  {'paperId': '036fd8b92722023742dc7fceb19a2ea1d56828de',
#   'title': 'Harvesting Textual and Structured Data from the HAL Publication Repository',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2313732350', 'name': 'Francis Kulumba'},
#    {'authorId': '51040671', 'name': 'Wissam Antoun'},
#    {'authorId': '2313732247', 'name': 'Guillaume Vimont'},
#    {'authorId': '2257165283', 'name': 'Laurent Romary'}]},
#  {'paperId': 'ca48013d99a608e800ae34388fe9fba9ea6ca280',
#   'title': 'The changing landscape of text mining: a review of approaches for ecology and evolution',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '8035829', 'name': 'M. Farrell'},
#    {'authorId': '2111507761', 'name': 'Nicolas Le Guillarme'},
#    {'authorId': '3715852', 'name': 'Liam Brierley'},
#    {'authorId': '2289107754', 'name': 'Bronwen Hunter'},
#    {'authorId': '2132547664', 'name': 'Daan Scheepens'},
#    {'authorId': '2289109059', 'name': 'Anna Willoughby'},
#    {'authorId': '2289109326', 'name': 'Andrew Yates'},
#    {'authorId': '3383502', 'name': 'N. Mideo'}]},
#  {'paperId': '3dd5ad34012164c4ec9c571a12cc6a7561683dea',
#   'title': 'A Comprehensive Survey of Scientific Large Language Models and Their Applications in Scientific Discovery',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2293820617', 'name': 'Yu Zhang'},
#    {'authorId': '29963551', 'name': 'Xiusi Chen'},
#    {'authorId': '2057050247', 'name': 'Bowen Jin'},
#    {'authorId': '2307033488', 'name': 'Sheng Wang'},
#    {'authorId': '2307565578', 'name': 'Shuiwang Ji'},
#    {'authorId': '2283212563', 'name': 'Wei Wang'},
#    {'authorId': '2257136881', 'name': 'Jiawei Han'}]},
#  {'paperId': '02487e9dfefdcb667be4dc160780321555662a2e',
#   'title': 'TEG-DB: A Comprehensive Dataset and Benchmark of Textual-Edge Graphs',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2304164966', 'name': 'Zhuofeng Li'},
#    {'authorId': '2307005368', 'name': 'Zixing Gou'},
#    {'authorId': '2307206343', 'name': 'Xiangnan Zhang'},
#    {'authorId': '2303435116', 'name': 'Zhongyuan Liu'},
#    {'authorId': '2275541506', 'name': 'Sirui Li'},
#    {'authorId': '2257349205', 'name': 'Yuntong Hu'},
#    {'authorId': '2284591355', 'name': 'Chen Ling'},
#    {'authorId': '2021011947', 'name': 'Zhengwu Zhang'},
#    {'authorId': '2257314969', 'name': 'Liang Zhao'}]},
#  {'paperId': '3a66e3a6fe1f9e1d95140f0c8fefc4ff964ba89d',
#   'title': 'Neural Methods for Data-to-text Generation',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '1928141171', 'name': 'Mandar Sharma'},
#    {'authorId': '73777508', 'name': 'A. Gogineni'},
#    {'authorId': '2258821789', 'name': 'Naren Ramakrishnan'}]},
#  {'paperId': '46c96074a4e33e90bc01b3c869cac9ea3a0b8fe7',
#   'title': 'Binarized Simplicial Convolutional Neural Networks',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '47971141', 'name': 'Yi Yan'},
#    {'authorId': '1691686', 'name': 'E. Kuruoglu'}]},
#  {'paperId': 'd33856de0e4f1499d6a48fdbd91e92700127b2fe',
#   'title': 'Improving Health Question Answering with Reliable and Time-Aware Evidence Retrieval',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2066962303', 'name': 'Juraj Vladika'},
#    {'authorId': '2243005966', 'name': 'Florian Matthes'}]},
#  {'paperId': 'e11c67919830bb0a29a86b05936d467227accc81',
#   'title': 'openalexR: An R-Tool for Collecting Bibliometric Data from OpenAlex',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://journal.r-project.org/articles/RJ-2023-089/RJ-2023-089.pdf',
#    'status': None},
#   'authors': [{'authorId': '2248919040', 'name': 'Massimo Aria'},
#    {'authorId': '2299300278', 'name': 'Trang Le'},
#    {'authorId': '32187939', 'name': 'C. Cuccurullo'},
#    {'authorId': '2165722548', 'name': 'Alessandra Belfiore'},
#    {'authorId': '2299054206', 'name': 'June Choe'}]},
#  {'paperId': 'c5a528afd98274902b4987b887f19ecd282ca8bd',
#   'title': 'BioBBC: a multi-feature model that enhances the detection of biomedical entities',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.nature.com/articles/s41598-024-58334-x.pdf',
#    'status': None},
#   'authors': [{'authorId': '1753416672', 'name': 'Hind Alamro'},
#    {'authorId': '2268847175', 'name': 'Takashi Gojobori'},
#    {'authorId': '46883364', 'name': 'M. Essack'},
#    {'authorId': '2109103060', 'name': 'Xin Gao'}]},
#  {'paperId': 'ce2beb2ad9efa56abdc59f4c613bda52cc11803c',
#   'title': 'Surveying biomedical relation extraction: a critical examination of current datasets and the proposal of a new resource',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://academic.oup.com/bib/article-pdf/25/3/bbae132/57221564/bbae132.pdf',
#    'status': None},
#   'authors': [{'authorId': '47451980', 'name': 'Ming-Siang Huang'},
#    {'authorId': '31763053', 'name': 'Jen-Chieh Han'},
#    {'authorId': '1781286404', 'name': 'Pei-Yen Lin'},
#    {'authorId': '2054452310', 'name': 'Yu-Ting You'},
#    {'authorId': '2285630764', 'name': 'Richard Tzong-Han Tsai'},
#    {'authorId': '2238570161', 'name': 'Wen-Lian Hsu'}]},
#  {'paperId': '6d66d55bd147f3f44830e86b4514da27aa00570f',
#   'title': 'pyKCN: A Python Tool for Bridging Scientific Knowledge',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2266767058', 'name': 'Zhenyuan Lu'},
#    {'authorId': '2157337597', 'name': 'Wei Li'},
#    {'authorId': '48147088', 'name': 'Burcu Ozek'},
#    {'authorId': '2284112591', 'name': 'Haozhou Zhou'},
#    {'authorId': '15897220', 'name': 'S. Radhakrishnan'},
#    {'authorId': '1941507', 'name': 'S. Kamarthi'}]},
#  {'paperId': '3f68ce247d93fae97f62f68fce175f0c3fdb425b',
#   'title': 'AI for Biomedicine in the Era of Large Language Models',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2293312099', 'name': 'Zhenyu Bi'},
#    {'authorId': '2293313831', 'name': 'Sajib Acharjee Dip'},
#    {'authorId': '2264478325', 'name': 'Daniel Hajialigol'},
#    {'authorId': '2293314240', 'name': 'Sindhura Kommu'},
#    {'authorId': '2265063862', 'name': 'Hanwen Liu'},
#    {'authorId': '2293550345', 'name': 'Meng Lu'},
#    {'authorId': '2263943236', 'name': 'Xuan Wang'}]},
#  {'paperId': '1571d11e5c22d0bdefce3f6ffa333f040a2e409d',
#   'title': 'MetaTron: advancing biomedical annotation empowering relation annotation and collaboration',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://bmcbioinformatics.biomedcentral.com/counter/pdf/10.1186/s12859-024-05730-9',
#    'status': None},
#   'authors': [{'authorId': '2051750606', 'name': 'Ornella Irrera'},
#    {'authorId': '39960971', 'name': 'S. Marchesin'},
#    {'authorId': '1508853659', 'name': 'Gianmaria Silvello'}]},
#  {'paperId': '61313651e06abb093dfa3fd4430a1f5b146d5b35',
#   'title': 'The geography of eco-innovations and sustainability transitions: a systematic comparison',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.degruyter.com/document/doi/10.1515/zfw-2022-0010/pdf',
#    'status': None},
#   'authors': [{'authorId': '2085072010', 'name': 'Hendrik Hansmeier'},
#    {'authorId': '2290769807', 'name': 'Henning Kroll'}]},
#  {'paperId': 'b4076046f55b8005d82489728df5ea24ffcd0281',
#   'title': 'The Geometric Structure of Topic Models',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '150148479', 'name': 'Johannes Hirth'},
#    {'authorId': '3439180', 'name': 'Tom Hanika'}]},
#  {'paperId': 'b798cf6af813638fab09a8af6ad0f3df6c241485',
#   'title': 'Benchmarking Retrieval-Augmented Generation for Medicine',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2048053804', 'name': 'Guangzhi Xiong'},
#    {'authorId': '2261406713', 'name': 'Qiao Jin'},
#    {'authorId': '2237094367', 'name': 'Zhiyong Lu'},
#    {'authorId': '2265729351', 'name': 'Aidong Zhang'}]},
#  {'paperId': 'f958280f92eb3b23608f5525b94b1a7c25dfff0b',
#   'title': 'On the Detection of Reviewer-Author Collusion Rings From Paper Bidding',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '1572164529', 'name': 'Steven Jecmen'},
#    {'authorId': '2325881690', 'name': 'Nihar B. Shah'},
#    {'authorId': '2283842982', 'name': 'Fei Fang'},
#    {'authorId': '3255268', 'name': 'L. Akoglu'}]},
#  {'paperId': 'adb68c59226e1c3ce5ea9c259c760a738a4870df',
#   'title': 'Hierarchical Tree-structured Knowledge Graph For Academic Insight Survey',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2402.04854', 'status': None},
#   'authors': [{'authorId': '2267861843', 'name': 'Jinghong Li'},
#    {'authorId': '2283133021', 'name': 'Huy Phan'},
#    {'authorId': '2191728751', 'name': 'Wen Gu'},
#    {'authorId': '2000912578', 'name': 'Koichi Ota'},
#    {'authorId': '2267751251', 'name': 'Shinobu Hasegawa'}]},
#  {'paperId': '89abfcec27ae484c368c25b0a1441aaa3bf6e408',
#   'title': 'What is the Consumer Attitude toward Healthcare Services? A Transfer Learning Approach for Detecting Emotions from Consumer Feedback',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2179569486', 'name': 'Bashar Alshouha'},
#    {'authorId': '1401773209', 'name': 'J. Serrano-Guerrero'},
#    {'authorId': '2192534791', 'name': 'David Elizondo'},
#    {'authorId': '2262493920', 'name': 'Francisco P. Romero'},
#    {'authorId': '1708929', 'name': 'J. A. Olivas'}]},
#  {'paperId': '67335a676ae3b4e17a4494edf19b2101484cd5b4',
#   'title': 'AI-assisted Blockchain-enabled Smart and Secure E-prescription Management Framework',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://dl.acm.org/doi/pdf/10.1145/3641279',
#    'status': None},
#   'authors': [{'authorId': '90187611', 'name': 'Siva Sai'},
#    {'authorId': '3185174', 'name': 'V. Chamola'}]},
#  {'paperId': 'f00ebe66750aa1996f78b30b8bb77cbf92fab085',
#   'title': 'Agriculture Named Entity Recognition—Towards FAIR, Reusable Scholarly Contributions in Agriculture',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.mdpi.com/2673-9585/4/1/1/pdf?version=1705678943',
#    'status': None},
#   'authors': [{'authorId': '2254258923', 'name': 'Jennifer D’Souza'}]},
#  {'paperId': 'dfbbea9a828d5e5ffeb22089a5386379d91a524f',
#   'title': 'Deep Learning in Physical Layer: Review on Data Driven End-to-End Communication Systems and Their Enabling Semantic Applications',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2280333448', 'name': 'Nazmul Islam'},
#    {'authorId': '40858979', 'name': 'Seokjoo Shin'}]},
#  {'paperId': '1347323c30180b5d5528abace9d36ba0d2dbf3c1',
#   'title': 'ACP-ESM: A novel framework for classification of anticancer peptides using protein-oriented transformer approach',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '3221527', 'name': 'Zeynep Hilal Kilimci'},
#    {'authorId': '2260336586', 'name': 'Mustafa Yalcin'}]},
#  {'paperId': '93886752191db25efd096a65af7b09df5c0a64e0',
#   'title': 'Data-Centric Foundation Models in Computational Healthcare: A Survey',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2225092617', 'name': 'Yunkun Zhang'},
#    {'authorId': '2175310417', 'name': 'Jin Gao'},
#    {'authorId': '2278471697', 'name': 'Zheling Tan'},
#    {'authorId': '2278404548', 'name': 'Lingfeng Zhou'},
#    {'authorId': '2128911389', 'name': 'Kexin Ding'},
#    {'authorId': '2179089074', 'name': 'Mu Zhou'},
#    {'authorId': '2278618280', 'name': 'Shaoting Zhang'},
#    {'authorId': '2278379365', 'name': 'Dequan Wang'}]},
#  {'paperId': 'ad1fda48e35b7e53556912715a2daef84e5363a3',
#   'title': 'Natural language processing for innovation search – Reviewing an emerging non-human innovation intermediary',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2223034633', 'name': 'Julian Just'}]},
#  {'paperId': 'bf71acf9684658be6bea32447d838640af679654',
#   'title': 'Evaluating Semantic Classifiers for Classification and Decision on Digital Library Data',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2304142418', 'name': 'Rong Xu'},
#    {'authorId': '2304146203', 'name': 'Jiaxing Chen'}]},
#  {'paperId': 'ed4e20bcd73b1138d3bb2ed4dbbf5e8b224ef5c7',
#   'title': 'mPLUG-PaperOwl: Scientific Diagram Analysis with the Multimodal Large Language Model',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '120897486', 'name': 'Anwen Hu'},
#    {'authorId': '37198550', 'name': 'Yaya Shi'},
#    {'authorId': '153194420', 'name': 'Haiyang Xu'},
#    {'authorId': '2153258288', 'name': 'Jiabo Ye'},
#    {'authorId': '2199011713', 'name': 'Qinghao Ye'},
#    {'authorId': '2114009661', 'name': 'Mingshi Yan'},
#    {'authorId': '143971529', 'name': 'Chenliang Li'},
#    {'authorId': '2256987633', 'name': 'Qi Qian'},
#    {'authorId': '2116921824', 'name': 'Ji Zhang'},
#    {'authorId': '2262080010', 'name': 'Fei Huang'}]},
#  {'paperId': '02f3c97ada83664938d2026f110c4a17c7e4db16',
#   'title': 'Relation Classification in Scientific Article Abstracts using SciBERT with Entity Marker',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2074346318', 'name': 'Nur Inayah'},
#    {'authorId': '70985093', 'name': 'Muhaza Liebenlito'},
#    {'authorId': '2267407251', 'name': 'Nina Fitriyati'},
#    {'authorId': '2089465406', 'name': 'Muhammad Manaqib'},
#    {'authorId': '2290293855', 'name': 'Nabila Aryanti'}]},
#  {'paperId': 'bca0bbd01ea917b7a9fe369288ea3ba03d3b1ff3',
#   'title': 'A Survey of Large Language Models in Medicine: Progress, Application, and Challenge',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2265945051', 'name': 'Hongjian Zhou'},
#    {'authorId': '2265754434', 'name': 'Boyang Gu'},
#    {'authorId': '2265783554', 'name': 'Xinyu Zou'},
#    {'authorId': '2265924823', 'name': 'Yiru Li'},
#    {'authorId': '2265803524', 'name': 'Sam S. Chen'},
#    {'authorId': '1800462890', 'name': 'Peilin Zhou'},
#    {'authorId': '2218869839', 'name': 'Junling Liu'},
#    {'authorId': '2147311343', 'name': 'Y. Hua'},
#    {'authorId': '2265754569', 'name': 'Chengfeng Mao'},
#    {'authorId': '2269413539', 'name': 'Xian Wu'},
#    {'authorId': '2266043640', 'name': 'Zheng Li'},
#    {'authorId': '2218961178', 'name': 'Fenglin Liu'}]},
#  {'paperId': '476991e5b9590febcd9f93ceea178be635958a9c',
#   'title': 'Cross-modal Multiple Granularity Interactive Fusion Network for Long Document Classification',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2145028549', 'name': 'Tengfei Liu'},
#    {'authorId': '2371027', 'name': 'Yongli Hu'},
#    {'authorId': '2261897593', 'name': 'Junbin Gao'},
#    {'authorId': '5305357', 'name': 'Yanfeng Sun'},
#    {'authorId': '2239088112', 'name': 'Baocai Yin'}]},
#  {'paperId': '7031506190d629c5ab73726498422401fe437d9c',
#   'title': 'Living Papers: A Language Toolkit for Augmented Scholarly Communication',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://dl.acm.org/doi/pdf/10.1145/3586183.3606791',
#    'status': None},
#   'authors': [{'authorId': '2260651136', 'name': 'Jeffrey Heer'},
#    {'authorId': '40963003', 'name': 'Matthew Conlen'},
#    {'authorId': '2260653039', 'name': 'Vishal Devireddy'},
#    {'authorId': '2260747290', 'name': 'Tu Nguyen'},
#    {'authorId': '1578154573', 'name': 'Josh Horowitz'}]},
#  {'paperId': 'f904784b97e48e7a93b74428e5333fb3c7b403c4',
#   'title': 'Classification and Clustering of Sentence-Level Embeddings of Scientific Articles Generated by Contrastive Learning',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://doi.org/10.5121/csit.2023.131923',
#    'status': None},
#   'authors': [{'authorId': '2064476217', 'name': 'Gustavo Bartz Guedes'},
#    {'authorId': '2262193850', 'name': 'Ana Estela Antunes da Silva'}]},
#  {'paperId': 'af3dfaf07b7d10de7928df851afccd99a041c9e3',
#   'title': 'Enhancing Biomedical Lay Summarisation with External Knowledge Graphs',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2188058199', 'name': 'Tomas Goldsack'},
#    {'authorId': '2212059523', 'name': 'Zhihao Zhang'},
#    {'authorId': '2261452385', 'name': 'Chen Tang'},
#    {'authorId': '2064492081', 'name': 'Carolina Scarton'},
#    {'authorId': '2244126309', 'name': 'Chenghua Lin'}]},
#  {'paperId': '39abce3268f309d5655247de0c442a28219df390',
#   'title': 'MedEval: A Multi-Level, Multi-Task, and Multi-Domain Medical Benchmark for Language Model Evaluation',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2116458151', 'name': 'Zexue He'},
#    {'authorId': '2256185766', 'name': 'Yu Wang'},
#    {'authorId': '2254201486', 'name': 'An Yan'},
#    {'authorId': '2261358086', 'name': 'Yao Liu'},
#    {'authorId': '2261287163', 'name': 'Eric Y. Chang'},
#    {'authorId': '2250624868', 'name': 'Amilcare Gentili'},
#    {'authorId': '2254271546', 'name': 'Julian J. McAuley'},
#    {'authorId': '2257436141', 'name': 'Chun-Nan Hsu'}]},
#  {'paperId': '8b53456cfb9c0f26614a830ff09073afdd0bbe6d',
#   'title': 'Citation Intent Classification and Its Supporting Evidence Extraction for Citation Graph Construction',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2260653336', 'name': 'Hong-Jin Tsai'},
#    {'authorId': '26958446', 'name': 'An-Zi Yen'},
#    {'authorId': '152354730', 'name': 'Hen-Hsen Huang'},
#    {'authorId': '2237850759', 'name': 'Hsin-Hsi Chen'}]},
#  {'paperId': '05a6ef4b442a7cd37f40ef93216f68e461439b95',
#   'title': 'Qlarify: Recursively Expandable Abstracts for Directed Information Retrieval over Scientific Papers',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '27083453', 'name': 'Raymond Fok'},
#    {'authorId': '48808806', 'name': 'Joseph Chee Chang'},
#    {'authorId': '50509991', 'name': 'Tal August'},
#    {'authorId': '144518215', 'name': 'Amy X. Zhang'},
#    {'authorId': '1780531', 'name': 'Daniel S. Weld'}]},
#  {'paperId': '1b5ddb30be6dcef45dd1eae1346ccd40610c3834',
#   'title': 'Building a large gene expression-cancer knowledge base with limited human annotations',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://academic.oup.com/database/article-pdf/doi/10.1093/database/baad061/51779434/baad061.pdf',
#    'status': None},
#   'authors': [{'authorId': '39960971', 'name': 'S. Marchesin'},
#    {'authorId': '2239486285', 'name': 'Laura Menotti'},
#    {'authorId': '103216433', 'name': 'Fabio Giachelle'},
#    {'authorId': '1688094', 'name': 'G. Silvello'},
#    {'authorId': '2239520675', 'name': 'Omar Alonso'}]},
#  {'paperId': '4b491211f7f29c3e9cdea4e4cd7ea4cc6f055595',
#   'title': 'T-Stochastic Graphs',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2237808534', 'name': 'Sijia Fang'},
#    {'authorId': '91122766', 'name': 'K. Rohe'}]},
#  {'paperId': 'a9d6f53f54409d3f33d84b1ade53624e532ba3e9',
#   'title': 'PreprintResolver: Improving Citation Quality by Resolving Published Versions of ArXiv Preprints using Literature Databases',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2309.01373', 'status': None},
#   'authors': [{'authorId': '1379516545', 'name': 'Louise Bloch'},
#    {'authorId': '1382580287', 'name': 'Johannes Ruckert'},
#    {'authorId': '2955567', 'name': 'C. Friedrich'}]},
#  {'paperId': '906c2b9544c7cba662f8ec5e0a8261103ae7f7c8',
#   'title': 'CRUISE-Screening: Living Literature Reviews Toolbox',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://dl.acm.org/doi/pdf/10.1145/3583780.3614736',
#    'status': None},
#   'authors': [{'authorId': '50320098', 'name': 'Wojciech Kusa'},
#    {'authorId': '2237802588', 'name': 'Petr Knoth'},
#    {'authorId': '1699657', 'name': 'A. Hanbury'}]},
#  {'paperId': '4b5445f4090dfd8e4da37d5750ea2709251abb15',
#   'title': 'Joint Semantic-Native Communication and Inference via Minimal Simplicial Structures',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2308.16789', 'status': None},
#   'authors': [{'authorId': '40538512', 'name': 'Qiyang Zhao'},
#    {'authorId': '2180261014', 'name': 'Han Zou'},
#    {'authorId': '1702172', 'name': 'M. Bennis'},
#    {'authorId': '2065834880', 'name': 'M. Debbah'},
#    {'authorId': '1967677', 'name': 'Ebtesam Almazrouei'},
#    {'authorId': '2236687641', 'name': 'Faouzi Bader'}]},
#  {'paperId': '2cfda2581748c2a47b3460c7255685b8c07740bf',
#   'title': 'Unlocking Hardware Security Assurance: The Potential of LLMs',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2308.11042', 'status': None},
#   'authors': [{'authorId': '2109496533', 'name': 'Xingyu Meng'},
#    {'authorId': '97966143', 'name': 'Amisha Srivastava'},
#    {'authorId': '2047943081', 'name': 'Ayush Arunachalam'},
#    {'authorId': '33293832', 'name': 'Avik Ray'},
#    {'authorId': '2232953063', 'name': 'Pedro Henrique Silva'},
#    {'authorId': '21037958', 'name': 'Rafail Psiakis'},
#    {'authorId': '1743038', 'name': 'Y. Makris'},
#    {'authorId': '2938259', 'name': 'K. Basu'}]},
#  {'paperId': '8030b9b333d56b7b1ab5453264ee81cf50bf0a80',
#   'title': 'The dynamics of higher-order novelties',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2307.06147', 'status': None},
#   'authors': [{'authorId': '80753146', 'name': 'G. Bona'},
#    {'authorId': '102605562', 'name': 'A. Bellina'},
#    {'authorId': '1400895082', 'name': 'G. D. Marzo'},
#    {'authorId': '2321456636', 'name': 'Angelo Petralia'},
#    {'authorId': '22186618', 'name': 'Iacopo Iacopini'},
#    {'authorId': '1795135', 'name': 'V. Latora'}]},
#  {'paperId': '1e3ef48abeef882e12f9553a1baf8944f3782c88',
#   'title': 'Several categories of Large Language Models (LLMs): A Short Survey',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2222525872', 'name': 'Saurabh Pahune'},
#    {'authorId': '2223291433', 'name': 'Manoj Chandrasekharan'}]},
#  {'paperId': '51d74cdf76eef5a15a55b3cd46d73b17f8a23574',
#   'title': 'Extracting fact-condition relation from geological papers via deep structured semantic model with multi-grained representation',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2109272783', 'name': 'Qizhi Chen'},
#    {'authorId': '2112202452', 'name': 'Hong Yao'},
#    {'authorId': '2223865921', 'name': 'Diange Zhou'},
#    {'authorId': '1390908242', 'name': 'Shengwen Li'},
#    {'authorId': '152339906', 'name': 'Lijun Dong'}]},
#  {'paperId': '5f60655778fd0e3cb849c719797585e0e97912a2',
#   'title': 'Divide and Conquer the EmpiRE: A Community-Maintainable Knowledge Graph of Empirical Research in Requirements Engineering',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.repo.uni-hannover.de/bitstream/123456789/16505/1/Divide_and_Conquer_the_EmpiRE_A_Community-Maintainable_Knowledge_Graph_of_Empirical_Research_in_Requirements_Engineering.pdf',
#    'status': None},
#   'authors': [{'authorId': '1969899', 'name': 'Oliver Karras'},
#    {'authorId': '2220832255', 'name': 'Felix Wernlein'},
#    {'authorId': '2174734722', 'name': 'Jil Klunder'},
#    {'authorId': '145044578', 'name': 'S. Auer'}]},
#  {'paperId': 'f1f774dd883260504f02763aa40776ccce23af80',
#   'title': 'RecBaselines2023: a new dataset for choosing baselines for recommender models',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2306.14292', 'status': None},
#   'authors': [{'authorId': '2199326150', 'name': 'Veronika Ivanova'},
#    {'authorId': '2132068332', 'name': 'Oleg Lashinin'},
#    {'authorId': '2065854229', 'name': 'Marina Ananyeva'},
#    {'authorId': '145374794', 'name': 'Sergey Kolesnikov'}]},
#  {'paperId': 'e35598d25849c983c30310d49c9647385d4c8867',
#   'title': 'Weakly Supervised Multi-Label Classification of Full-Text Scientific Papers',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2306.14003', 'status': None},
#   'authors': [{'authorId': '49891156', 'name': 'Yu Zhang'},
#    {'authorId': '2057050247', 'name': 'Bowen Jin'},
#    {'authorId': '29963551', 'name': 'Xiusi Chen'},
#    {'authorId': '2203364310', 'name': 'Yan-Jun Shen'},
#    {'authorId': '48379289', 'name': 'Yunyi Zhang'},
#    {'authorId': '145391513', 'name': 'Yu Meng'},
#    {'authorId': '2111759643', 'name': 'Jiawei Han'}]},
#  {'paperId': '0c4a1d3bb96df512037c6f0ae7630aa696e09180',
#   'title': 'Vocabulary Matters: An Annotation Pipeline and Four Deep Learning Algorithms for Enzyme Named Entity Recognition',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.biorxiv.org/content/biorxiv/early/2023/06/24/2023.06.23.546229.full.pdf',
#    'status': None},
#   'authors': [{'authorId': '2145320451', 'name': 'Meiqi Wang'},
#    {'authorId': '2220758263', 'name': 'Avish Vijayaraghavan'},
#    {'authorId': '144866362', 'name': 'Tim Beck'},
#    {'authorId': '3081379', 'name': 'J. Posma'}]},
#  {'paperId': 'e7356e83c0bd60cb4d6d0283d3cf5040ed55bdf9',
#   'title': 'CORE: A Global Aggregation Service for Open Access Papers',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.nature.com/articles/s41597-023-02208-w.pdf',
#    'status': None},
#   'authors': [{'authorId': '1848764', 'name': 'Petr Knoth'},
#    {'authorId': '1839605', 'name': 'Drahomira Herrmannova'},
#    {'authorId': '2066327521', 'name': 'M. Cancellieri'},
#    {'authorId': '2300458', 'name': 'Lucas Anastasiou'},
#    {'authorId': '2081444', 'name': 'Nancy Pontika'},
#    {'authorId': '2638873', 'name': 'Samuel Pearce'},
#    {'authorId': '2942586', 'name': 'B. Gyawali'},
#    {'authorId': '2064119650', 'name': 'David Pride'}]},
#  {'paperId': 'a6a88bde13b6247f4fa91c4ede9cbf91409ee646',
#   'title': 'Online Edge Flow Prediction Over Expanding Simplicial Complexes',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://repository.tudelft.nl/file/File_15a90a2e-1f1d-42f0-a6b9-4e032d94bf46',
#    'status': None},
#   'authors': [{'authorId': '2040416515', 'name': 'Maosheng Yang'},
#    {'authorId': '51013185', 'name': 'Bishwadeep Das'},
#    {'authorId': '1815210', 'name': 'E. Isufi'}]},
#  {'paperId': '382301f0a9a85c298c6ec51ba4434ba040db960c',
#   'title': 'Accelerating science with human-aware artificial intelligence',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2313086', 'name': 'J. Sourati'},
#    {'authorId': '144002439', 'name': 'James A. Evans'}]},
#  {'paperId': '116145af7e956b23d0d9a81fdad8cb4f9a166531',
#   'title': 'SEARCHFORMER: Semantic patent embeddings by siamese transformers for prior art search',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2213777304', 'name': 'Konrad Vowinckel'},
#    {'authorId': '1722997', 'name': 'Volker Hähnke'}]},
#  {'paperId': '120c3c98818ce29dbb9847f221050b2a2a82d4ed',
#   'title': 'Extensive Evaluation of Transformer-based Architectures for Adverse Drug Events Extraction',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2127599599', 'name': 'Simone Scaboro'},
#    {'authorId': '1805998814', 'name': 'Beatrice Portelli'},
#    {'authorId': '3433809', 'name': 'Emmanuele Chersoni'},
#    {'authorId': '150991377', 'name': 'Enrico Santus'},
#    {'authorId': '2163190285', 'name': 'Giuseppe Serra'}]},
#  {'paperId': 'b17969990b3745a494f8fcadae6c8cd0426dc3ec',
#   'title': 'Pre-training Multi-task Contrastive Learning Models for Scientific Literature Understanding',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2305.14232', 'status': None},
#   'authors': [{'authorId': '49891156', 'name': 'Yu Zhang'},
#    {'authorId': '47413820', 'name': 'Hao Cheng'},
#    {'authorId': '123188251', 'name': 'Zhihong Shen'},
#    {'authorId': '46522098', 'name': 'Xiaodong Liu'},
#    {'authorId': '2115740680', 'name': 'Yejiang Wang'},
#    {'authorId': '48441311', 'name': 'Jianfeng Gao'}]},
#  {'paperId': '8eaebaf8fc01049ee2812607642f1ac0dabc6c6e',
#   'title': 'Beyond Good Intentions: Reporting the Research Landscape of NLP for Social Good',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2305.05471', 'status': None},
#   'authors': [{'authorId': '2111747266', 'name': 'F. González'},
#    {'authorId': '2111472502', 'name': 'Zhijing Jin'},
#    {'authorId': '2190982849', 'name': 'Jade Beydoun'},
#    {'authorId': '1707625', 'name': 'B. Scholkopf'},
#    {'authorId': '2041698667', 'name': 'Tom Hope'},
#    {'authorId': '2790926', 'name': 'Mrinmaya Sachan'},
#    {'authorId': '2105984203', 'name': 'Rada Mihalcea'}]},
#  {'paperId': '911fe48fc5b6ca5589b48521660db436065cf9c0',
#   'title': 'PGB: A PubMed Graph Benchmark for Heterogeneous Network Representation Learning',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2305.02691', 'status': None},
#   'authors': [{'authorId': '150091866', 'name': 'E. Lee'},
#    {'authorId': '152316651', 'name': 'Joyce Ho'}]},
#  {'paperId': '033cd044b41868c4d1713d917b6ff73f919783c5',
#   'title': 'KEBLM: Knowledge-Enhanced Biomedical Language Models',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '145242558', 'name': 'T. Lai'},
#    {'authorId': '143869012', 'name': 'Chengxiang Zhai'},
#    {'authorId': '2072975661', 'name': 'Heng Ji'}]},
#  {'paperId': '32382cfa1e662de9ccee317ba11e1117b5c99bf7',
#   'title': 'CCpdf: Building a High Quality Corpus for Visually Rich Documents from Web Crawl Data',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2304.14953', 'status': None},
#   'authors': [{'authorId': '153451419', 'name': 'M. Turski'},
#    {'authorId': '2106450032', 'name': 'Tomasz Stanislawek'},
#    {'authorId': '145104037', 'name': 'Karol Kaczmarek'},
#    {'authorId': '2215774519', 'name': 'Pawel Dyda'},
#    {'authorId': '2064873282', 'name': "Filip Grali'nski"}]},
#  {'paperId': '4d7500a1a5aeb83663527b17c002d7da173ef907',
#   'title': 'RCMR 280k: Refined Corpus for Move Recognition Based on PubMed Abstracts',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://direct.mit.edu/dint/article-pdf/doi/10.1162/dint_a_00214/2080052/dint_a_00214.pdf',
#    'status': None},
#   'authors': [{'authorId': '2189130850', 'name': 'Jie Li'},
#    {'authorId': '151486833', 'name': 'Gaihong Yu'},
#    {'authorId': '50317066', 'name': 'Zhixiong Zhang'}]},
#  {'paperId': 'cbdf6e77aa6cfd650a49e8f0ae95726c1e97540a',
#   'title': 'Evaluating Digital Library Search Systems by Using Formal Process Modelling',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2304.11651', 'status': None},
#   'authors': [{'authorId': '46351484', 'name': 'Christin Katharina Kreutz'},
#    {'authorId': '2165313022', 'name': 'Martin Blum'},
#    {'authorId': '34588911', 'name': 'Philipp Schaer'},
#    {'authorId': '1727566', 'name': 'Ralf Schenkel'},
#    {'authorId': '2638784', 'name': 'B. Weyers'}]},
#  {'paperId': '4a1cd12aeda0356ed4a1c30533313a8b68f9a55b',
#   'title': 'Enriching Simple Keyword Queries for Domain-Aware Narrative Retrieval',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2304.07604', 'status': None},
#   'authors': [{'authorId': '77790220', 'name': 'H. Kroll'},
#    {'authorId': '46351484', 'name': 'Christin Katharina Kreutz'},
#    {'authorId': '2214580618', 'name': 'Pascal Sackhoff'},
#    {'authorId': '1720266', 'name': 'Wolf-Tilo Balke'}]},
#  {'paperId': '1ad9a295ea841599383e5ae3e88381438d4a7db3',
#   'title': 'Evaluation of GPT and BERT-based models on identifying proteinprotein interactions in biomedical text',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2303.17728', 'status': None},
#   'authors': [{'authorId': '35668704', 'name': 'Hasin Rehana'},
#    {'authorId': '2214609905', 'name': 'Nur Bengisu Çam'},
#    {'authorId': '2180883959', 'name': 'Mert Basmaci'},
#    {'authorId': '1679167', 'name': 'Y. He'},
#    {'authorId': '2113900183', 'name': 'Arzucan Özgür'},
#    {'authorId': '1747690', 'name': 'J. Hur'}]},
#  {'paperId': '812b6f4dd78edb52959a660c1ac3cdcf5f8e13c6',
#   'title': 'Bat4RCT: A suite of benchmark data and baseline methods for text classification of randomized controlled trials',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0283342&type=printable',
#    'status': None},
#   'authors': [{'authorId': '2109208555', 'name': 'Jenna Kim'},
#    {'authorId': '2110005332', 'name': 'Jinmo Kim'},
#    {'authorId': '2115972785', 'name': 'Aejin Lee'},
#    {'authorId': '47964260', 'name': 'Jinseok Kim'}]},
#  {'paperId': '4245c6eb4f59ad5faf9ed9dbc2f0bea8dc393a6a',
#   'title': 'Disparity in the Evolving COVID-19 Collaboration Network',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2303.02473', 'status': None},
#   'authors': [{'authorId': '47995159', 'name': 'Hui-Rong Xu'},
#    {'authorId': '151192140', 'name': 'Redoan Rahman'},
#    {'authorId': '2141351739', 'name': 'A. Jaiswal'},
#    {'authorId': '2053708764', 'name': 'Julia Fensel'},
#    {'authorId': '2210796518', 'name': 'Abhinav Peri'},
#    {'authorId': '1382324502', 'name': 'Katya Peri'},
#    {'authorId': '144135987', 'name': 'G. Weber'},
#    {'authorId': '2116500622', 'name': 'Ying Ding'}]},
#  {'paperId': '6c48f1a429e8371ebdac412602629cb6472db1a8',
#   'title': 'Domain Word Extension Using Curriculum Learning',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.mdpi.com/1424-8220/23/6/3064/pdf?version=1678689738',
#    'status': None},
#   'authors': [{'authorId': '1643995043', 'name': 'S. Seong'},
#    {'authorId': '2007875', 'name': 'Jeongwon Cha'}]},
#  {'paperId': '817acf0bec0933728f7b1b2bcd8689910cd61b85',
#   'title': 'Generation of Highlights From Research Papers Using Pointer-Generator Networks and SciBERT Embeddings',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://ieeexplore.ieee.org/ielx7/6287639/6514899/10172215.pdf',
#    'status': None},
#   'authors': [{'authorId': '66695795', 'name': 'Tohida Rehman'},
#    {'authorId': '11575056', 'name': 'Debarshi Kumar Sanyal'},
#    {'authorId': '1379534518', 'name': 'S. Chattopadhyay'},
#    {'authorId': '34934281', 'name': 'Plaban Kumar Bhowmick'},
#    {'authorId': '2153318545', 'name': 'P. Das'}]},
#  {'paperId': 'e7dcdfb7734d59b97f825cce8b3105a2d9b14d10',
#   'title': 'The Effect of Metadata on Scientific Literature Tagging: A Cross-Field Cross-Model Study',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2302.03341', 'status': None},
#   'authors': [{'authorId': '49891156', 'name': 'Yu Zhang'},
#    {'authorId': '2057050247', 'name': 'Bowen Jin'},
#    {'authorId': '2152206948', 'name': 'Qi Zhu'},
#    {'authorId': '145391513', 'name': 'Yu Meng'},
#    {'authorId': '2111759643', 'name': 'Jiawei Han'}]},
#  {'paperId': '1a37f43db8108af003bc9af181460ddaacf9e815',
#   'title': 'Convolutional Learning on Simplicial Complexes',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2301.11163', 'status': None},
#   'authors': [{'authorId': '2040416515', 'name': 'Maosheng Yang'},
#    {'authorId': '1815210', 'name': 'E. Isufi'}]},
#  {'paperId': '1712eaa82a2e3d081538a17e06416330fac0a0d8',
#   'title': 'Energy Efficient Semantic Communication Over Wireless Networks With Rate Splitting',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2301.01987', 'status': None},
#   'authors': [{'authorId': '2155029411', 'name': 'Zhaohui Yang'},
#    {'authorId': '2107942948', 'name': 'Mingzhe Chen'},
#    {'authorId': '2156123228', 'name': 'Zhaoyang Zhang'},
#    {'authorId': '30745651', 'name': 'Chongwen Huang'}]},
#  {'paperId': 'b74aec118f2b62ae05b04f1b66ab79c2e5b873c0',
#   'title': 'MRT: Tracing the Evolution of Scientific Publications',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2075292864', 'name': 'Da Yin'},
#    {'authorId': '1403621152', 'name': 'W. Tam'},
#    {'authorId': '2055623340', 'name': 'Ming Ding'},
#    {'authorId': '2109541439', 'name': 'Jie Tang'}]},
#  {'paperId': 'cc7fbba314bcf99cdcff74e6a12bf5a777350a54',
#   'title': 'Logic Mill - A Knowledge Navigation System',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2301.00200', 'status': None},
#   'authors': [{'authorId': '21708612', 'name': 'Sebastian Erhardt'},
#    {'authorId': '2319032', 'name': 'Mainak Ghosh'},
#    {'authorId': '2199116561', 'name': 'Erik Buunk'},
#    {'authorId': '2061589845', 'name': 'Michael E. Rose'},
#    {'authorId': '1697838', 'name': 'D. Harhoff'}]},
#  {'paperId': 'cfcfe9fd697e98ad2508b4bf95dad16390f66938',
#   'title': 'Chaining and the temporal dynamics of scientists’ publishing behaviour',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0278389&type=printable',
#    'status': None},
#   'authors': [{'authorId': '1381444447', 'name': 'Emmy Liu'},
#    {'authorId': '2115684149', 'name': 'Yang Xu'}]},
#  {'paperId': '958bb3831589246fe5b6b58cf99e3b65c58d027f',
#   'title': 'Multi-modal Molecule Structure-text Model for Text-based Retrieval and Editing',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2212.10789', 'status': None},
#   'authors': [{'authorId': '1563693999', 'name': 'Shengchao Liu'},
#    {'authorId': '2066304514', 'name': 'Weili Nie'},
#    {'authorId': '50097250', 'name': 'Chengpeng Wang'},
#    {'authorId': '2121696601', 'name': 'Jiarui Lu'},
#    {'authorId': '88820329', 'name': 'Zhuoran Qiao'},
#    {'authorId': '2146021664', 'name': 'Ling Liu'},
#    {'authorId': '2115855484', 'name': 'Jian Tang'},
#    {'authorId': '2723309', 'name': 'Chaowei Xiao'},
#    {'authorId': '2047844', 'name': 'Anima Anandkumar'}]},
#  {'paperId': 'cc71b982828fd38f581c0257502d9b36744f0005',
#   'title': 'Named Entity Recognition Using Transfer Learning with the Fusion of Pre-trained SciBERT Language Model and Bi-directional Long Short Term Memory',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '144776556', 'name': 'M. Usha'},
#    {'authorId': '2210520361', 'name': 'Afia Mukarrama Smrity'},
#    {'authorId': '3196572', 'name': 'Sunanda Das'}]},
#  {'paperId': '054dd061a42086ab2758141655bebd7559b144fa',
#   'title': 'SciFoodNER: Food Named Entity Recognition for Scientific Text',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://dirros.openscience.si/Dokument.php?lang=slv&id=22530&dn=',
#    'status': None},
#   'authors': [{'authorId': '2123076219', 'name': 'Gjorgjina Cenikj'},
#    {'authorId': '73349536', 'name': 'G. Petelin'},
#    {'authorId': '98356713', 'name': 'B. Korousic-Seljak'},
#    {'authorId': '35604507', 'name': 'T. Eftimov'}]},
#  {'paperId': '768403710ec37fe612257384b19bf8f1c7bcce72',
#   'title': "Formative assessment strategies for students' conceptions - The potential of learning analytics",
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.repo.uni-hannover.de/bitstream/123456789/13762/1/Formative_assessment_strategies.pdf',
#    'status': None},
#   'authors': [{'authorId': '2094291242', 'name': 'Judith Stanja'},
#    {'authorId': '2133450085', 'name': 'Wolfgang Gritz'},
#    {'authorId': '1974715', 'name': 'Johannes Krugel'},
#    {'authorId': '2288008', 'name': 'Anett Hoppe'},
#    {'authorId': '2192135330', 'name': 'Sarah Dannemann'}]},
#  {'paperId': 'b6fba18ca329347c330262edb71f56bde08c29e1',
#   'title': 'The National Library of Medicine indexer assignment dataset: A new large‐scale dataset for reviewer assignment research',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/asi.24722',
#    'status': None},
#   'authors': [{'authorId': '153410529', 'name': 'Alastair R. Rae'},
#    {'authorId': '40536802', 'name': 'James G. Mork'},
#    {'authorId': '1398175407', 'name': 'Dina Demner-Fushman'}]},
#  {'paperId': '94e99c02b61f2d8b727f08e08924146705a614df',
#   'title': 'Understanding knowledge role transitions: A perspective of knowledge codification',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://direct.mit.edu/qss/article-pdf/doi/10.1162/qss_a_00221/2065413/qss_a_00221.pdf',
#    'status': None},
#   'authors': [{'authorId': '2109825013', 'name': 'Jinqing Yang'},
#    {'authorId': '2153424616', 'name': 'Wei Lu'},
#    {'authorId': '2145587478', 'name': 'Yong Huang'},
#    {'authorId': '2283732', 'name': 'Qikai Cheng'},
#    {'authorId': '48571183', 'name': 'Li Zhang'},
#    {'authorId': '2149206180', 'name': 'Shengzhi Huang'}]},
#  {'paperId': '14644be339b0805aa8098a97f61fe2398cc770a9',
#   'title': 'SMAuC - The Scientific Multi-Authorship Corpus',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2211.02477', 'status': None},
#   'authors': [{'authorId': '2190038398', 'name': 'Philipp Sauer'},
#    {'authorId': '9537652', 'name': 'Janek Bevendorff'},
#    {'authorId': '2124424844', 'name': 'Lukas Gienapp'},
#    {'authorId': '2120814205', 'name': 'Wolfgang Kircheis'},
#    {'authorId': '2190038260', 'name': 'Erik Korner'},
#    {'authorId': '1405867539', 'name': 'Benno Stein'},
#    {'authorId': '3046200', 'name': 'Martin Potthast'}]},
#  {'paperId': '3605d3aacfa071d9c97b06d834f021baa61625f4',
#   'title': 'Enriched entity representation of knowledge graph for text generation',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://link.springer.com/content/pdf/10.1007/s40747-022-00898-0.pdf',
#    'status': None},
#   'authors': [{'authorId': '2088584905', 'name': 'Kaile Shi'},
#    {'authorId': '50320934', 'name': 'Xiaoyan Cai'},
#    {'authorId': '49576312', 'name': 'Libin Yang'},
#    {'authorId': '2109858731', 'name': 'Jintao Zhao'}]},
#  {'paperId': '7e0fda71cc2e561385c0a2e29f5a81654a11157f',
#   'title': 'VarMAE: Pre-training of Variational Masked Autoencoder for Domain-adaptive Language Understanding',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2211.00430', 'status': None},
#   'authors': [{'authorId': '120427046', 'name': 'Dou Hu'},
#    {'authorId': '2112801129', 'name': 'Xiaolong Hou'},
#    {'authorId': '2158315873', 'name': 'Xiyang Du'},
#    {'authorId': '2109138287', 'name': 'Mengyuan Zhou'},
#    {'authorId': '21833875', 'name': 'Lian-Xin Jiang'},
#    {'authorId': '115656171', 'name': 'Yang Mo'},
#    {'authorId': '2158504949', 'name': 'Xiaofeng Shi'}]},
#  {'paperId': 'fdf8a75d2420a8f6bd05091a7f6bc52f6641cc80',
#   'title': 'Categorizing Citation Relations in Scientific Papers Based on the Contributions of Cited Papers',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2215388241', 'name': 'Po-Chun Chen'},
#    {'authorId': '2611607', 'name': 'Hen-Hsen Huang'},
#    {'authorId': '153924342', 'name': 'Hsin-Hsi Chen'}]},
#  {'paperId': '4a236906f5bed6385c7b3bf3f10a0099e41d4566',
#   'title': 'Semantic-Native Communication: A Simplicial Complex Perspective',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://arxiv.org/pdf/2210.16970', 'status': None},
#   'authors': [{'authorId': '40538512', 'name': 'Qiyang Zhao'},
#    {'authorId': '1702172', 'name': 'M. Bennis'},
#    {'authorId': '145118318', 'name': 'M. Debbah'},
#    {'authorId': '2070007373', 'name': 'Daniella Harth da Costa'}]},
#  {'paperId': 'f5b484e7e490c9e727575086877cecdb121f55dc',
#   'title': 'Visual Exploration of Literature with Argo Scholar',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://dl.acm.org/doi/pdf/10.1145/3511808.3557177',
#    'status': None},
#   'authors': [{'authorId': '2149141974', 'name': 'K. Li'},
#    {'authorId': '2115537671', 'name': 'Haoyang Yang'},
#    {'authorId': '2187856448', 'name': 'Evan Montoya'},
#    {'authorId': '1910628856', 'name': 'Anish Upadhayay'},
#    {'authorId': '2149134030', 'name': 'Zhiyan Zhou'},
#    {'authorId': '1742192721', 'name': 'Jon Saad-Falcon'},
#    {'authorId': '1793506', 'name': 'Duen Horng Chau'}]},
#  {'paperId': '42b2fd8a0ab69281022de528c591c665f5f2ad3b',
#   'title': 'A Multi-Domain Benchmark for Personalized Search Evaluation',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://dl.acm.org/doi/pdf/10.1145/3511808.3557536',
#    'status': None},
#   'authors': [{'authorId': '52211445', 'name': 'Elias Bassani'},
#    {'authorId': '2187856026', 'name': 'Pranav Kasela'},
#    {'authorId': '3106437', 'name': 'Alessandro Raganato'},
#    {'authorId': '145645971', 'name': 'G. Pasi'}]},
#  {'paperId': 'e92b2ada3a8112426946f3acd8991dbc74d4b311',
#   'title': 'KnowledgeShovel: An AI-in-the-Loop Document Annotation System for Scientific Knowledge Base Construction',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2210.02830', 'status': None},
#   'authors': [{'authorId': '2116577679', 'name': 'Shao Zhang'},
#    {'authorId': '2117724696', 'name': 'Yuting Jia'},
#    {'authorId': '2149189560', 'name': 'Hui Xu'},
#    {'authorId': '36743361', 'name': 'Dakuo Wang'},
#    {'authorId': '34997918', 'name': 'Toby Jia-Jun Li'},
#    {'authorId': '2155576705', 'name': 'Ying Wen'},
#    {'authorId': '2107937507', 'name': 'Xinbing Wang'},
#    {'authorId': '2111168706', 'name': 'Cheng Zhou'}]},
#  {'paperId': '428194865ce5732c3c53f548b3d56485e8c7f4eb',
#   'title': 'Community as a Vague Operator: Epistemological Questions for a Critical Heuristics of Community Detection Algorithms',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2060790704', 'name': 'Dominik J. Schindler'},
#    {'authorId': '84076745', 'name': 'Matthew Fuller'}]},
#  {'paperId': '00f4e66a3eb2fa02063d83da1e5afe19242a282e',
#   'title': 'Clustering Semantic Predicates in the Open Research Knowledge Graph',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'http://arxiv.org/pdf/2210.02034', 'status': None},
#   'authors': [{'authorId': '2186981191', 'name': 'Omar Arab Oghli'},
#    {'authorId': '1789682566', 'name': 'J. D’Souza'},
#    {'authorId': '145044578', 'name': 'S. Auer'}]},
#  {'paperId': '1b2139b38e6a9ded0c161a6bbed39a5cf09c03f0',
#   'title': 'A Dataset of Alt Texts from HCI Publications: Analyses and Uses Towards Producing More Descriptive Alt Texts of Data Visualizations in Scientific Papers',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://dl.acm.org/doi/pdf/10.1145/3517428.3544796',
#    'status': None},
#   'authors': [{'authorId': '2177360735', 'name': 'S. Chintalapati'},
#    {'authorId': '2699105', 'name': 'Jonathan Bragg'},
#    {'authorId': '31860505', 'name': 'Lucy Lu Wang'}]},
#  {'paperId': 'dfbe1fcd18742d71d2807506120aab24485491c8',
#   'title': 'Constructing marine expert management knowledge graph based on Trellisnet-CRF',
#   'isOpenAccess': True,
# ...
#   'title': 'Towards Fairness-Aware Ranking by Defining Latent Groups Using Inferred Features',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2150671441', 'name': 'Yunhe Feng'},
#    {'authorId': '2007656135', 'name': 'Daniel Saelid'},
#    {'authorId': '2149140719', 'name': 'Ke Li'},
#    {'authorId': '2986776', 'name': 'Ruoyuan Gao'},
#    {'authorId': '144797719', 'name': 'C. Shah'}]},
#  {'paperId': '3faccd2f58466e1767957dda6faa6c29b393cef4',
#   'title': 'The Semantic Web: 17th International Conference, ESWC 2020, Heraklion, Crete, Greece, May 31–June 4, 2020, Proceedings',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://link.springer.com/content/pdf/bfm:978-3-030-49461-2/1?pdf=chapter%20toc',
#    'status': None},
#   'authors': [{'authorId': '1775662', 'name': 'A. Harth'},
#    {'authorId': '2601335', 'name': 'S. Kirrane'},
#    {'authorId': '1802726', 'name': 'Heiko Paulheim'},
#    {'authorId': '1953113', 'name': 'Anna Lisa Gentile'},
#    {'authorId': '49817869', 'name': 'P. Haase'},
#    {'authorId': '1708906', 'name': 'Michael Cochez'},
#    {'authorId': '1743774', 'name': 'E. Bertino'},
#    {'authorId': '1712107', 'name': 'A. N. Ngomo'},
#    {'authorId': '2333981', 'name': 'Anisa Rula'}]},
#  {'paperId': None,
#   'title': '19-Chen Xiaoli.indd',
#   'isOpenAccess': None,
#   'openAccessPdf': None,
#   'authors': []},
#  {'paperId': '50fe89d2109f1f186e5e91aa8a7853d92a85daee',
#   'title': 'Evaluating Pretrained Transformer Models for Citation Recommendation',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '143744603', 'name': 'Rodrigo Nogueira'},
#    {'authorId': None, 'name': 'Zhiying Jiang'},
#    {'authorId': '1979489', 'name': 'Kyunghyun Cho'},
#    {'authorId': '145580839', 'name': 'Jimmy J. Lin'}]},
#  {'paperId': 'cdede45f350038a46bac239d6ff8c548ac2945ee',
#   'title': 'Self-supervised context-aware COVID-19 document exploration through atlas grounding',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '1388019229', 'name': 'Dusan Grujicic'},
#    {'authorId': '51016420', 'name': 'Gorjan Radevski'},
#    {'authorId': '1704728', 'name': 'T. Tuytelaars'},
#    {'authorId': '1758219', 'name': 'Matthew B. Blaschko'}]},
#  {'paperId': '5c5751d45e298cea054f32b392c12c61027d2fe7',
#   'title': 'S2ORC: The Semantic Scholar Open Research Corpus',
#   'isOpenAccess': True,
#   'openAccessPdf': {'url': 'https://www.aclweb.org/anthology/2020.acl-main.447.pdf',
#    'status': None},
#   'authors': [{'authorId': '46258841', 'name': 'Kyle Lo'},
#    {'authorId': '31860505', 'name': 'Lucy Lu Wang'},
#    {'authorId': '2060376981', 'name': 'Mark Neumann'},
#    {'authorId': '143967880', 'name': 'Rodney Michael Kinney'},
#    {'authorId': '1780531', 'name': 'Daniel S. Weld'}]},
#  {'paperId': '1dd19753c01476612db6f668967ded7b859deb83',
#   'title': 'A Practical Guide to Hybrid Natural Language Processing: Combining Neural Models and Knowledge Graphs for NLP',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2420472', 'name': 'José Manuél Gómez-Pérez'},
#    {'authorId': '2213589', 'name': 'R. Denaux'},
#    {'authorId': '1401950156', 'name': 'Andres Garcia-Silva'}]},
#  {'paperId': 'a997d6e253f08a3e589432c611d6d2a3097d7629',
#   'title': 'Research Exchange - A Collaborative Paper Annotation Tool',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '26161085', 'name': 'Kalpesh Krishna'},
#    {'authorId': '2927754', 'name': 'Yue-Cen Liu'},
#    {'authorId': '91093379', 'name': 'Shashank Mehrotra'},
#    {'authorId': '2292174721', 'name': 'Jiazheng Zhu'}]},
#  {'paperId': 'd05ebd2299bc8007edf9422eb2f7b4466e3cf4f4',
#   'title': 'Database and Expert Systems Applications: DEXA 2020 International Workshops BIOKDD, IWCFS and MLKgraphs, Bratislava, Slovakia, September 14–17, 2020, Proceedings',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2109783258', 'name': 'Mohit Kumar'},
#    {'authorId': '2072997564', 'name': 'David Brunner'},
#    {'authorId': '145368221', 'name': 'B. Moser'},
#    {'authorId': '1712659', 'name': 'B. Freudenthaler'}]},
#  {'paperId': '1955c6821a5dd94baaa3fe96f4e50c071f6fa87e',
#   'title': 'ScholarLensViz: A Visualization Framework for Transparency in Semantic User Profiles',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '35202452', 'name': 'Felicitas Löffler'},
#    {'authorId': '1509417836', 'name': 'Valentin Wesp'},
#    {'authorId': '3322958', 'name': 'Samira Babalou'},
#    {'authorId': '1646628577', 'name': 'P. Kahn'},
#    {'authorId': '2074203173', 'name': 'René Lachmann'},
#    {'authorId': '2001991', 'name': 'Bahar Sateli'},
#    {'authorId': '145364793', 'name': 'R. Witte'},
#    {'authorId': '1389035902', 'name': 'B. König-Ries'}]},
#  {'paperId': '5f68c2fc47408d10013c36664495b1a489087053',
#   'title': 'Digital Libraries at Times of Massive Societal Transition: 22nd International Conference on Asia-Pacific Digital Libraries, ICADL 2020, Kyoto, Japan, November 30 – December 1, 2020, Proceedings',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '3280058', 'name': 'Emi Ishita'},
#    {'authorId': '2807302', 'name': 'N. Pang'},
#    {'authorId': '2144328695', 'name': 'Lihong Zhou'}]},
#  {'paperId': '4d515133e301691863dc81e5c73046b2eab0f3f7',
#   'title': 'PreFace: Faceted Retrieval of Prerequisites Using Domain-Specific Knowledge Bases',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2401391', 'name': 'P. Upadhyay'},
#    {'authorId': '1680366', 'name': 'Maya Ramanath'}]},
#  {'paperId': '9519b72e2bf6906af33b431a0ea58a8c1e4c48b1',
#   'title': 'Graph To Coherent Text: Passage Generation from Knowledge Graphs by Exploiting Edge Representations in Sentential Contexts',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '3456974', 'name': 'Litton J. Kurisinkel'},
#    {'authorId': '2185019', 'name': 'Nancy F. Chen'}]},
#  {'paperId': '738349f595421b70f80a8d8fed7f70e55fa5f475',
#   'title': 'The University of Maryland at the TREC 2020 Fair Ranking Track',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '153534926', 'name': 'Mahmoud F. Sayed'},
#    {'authorId': '1737250', 'name': 'Douglas W. Oard'}]},
#  {'paperId': 'f91ac07cc5716c25304ebe4385ec3b41b67f57b9',
#   'title': 'University of Glasgow Terrier Team at the TREC 2020 Fair Ranking Track',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '38657905', 'name': 'Graham Mcdonald'},
#    {'authorId': '1698205', 'name': 'I. Ounis'}]},
#  {'paperId': '7ff0d6253469c02245c1bd321e97a96813b612d4',
#   'title': 'NaCTeM-UoM @ CL-SciSumm 2019',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '36259430', 'name': 'Chrysoula Zerva'},
#    {'authorId': '3209478', 'name': 'Minh-Quoc Nghiem'},
#    {'authorId': '48182862', 'name': 'Nhung T. H. Nguyen'},
#    {'authorId': '1881965', 'name': 'S. Ananiadou'}]},
#  {'paperId': '9bbe5de594c53275e3123417c5636243677649ae',
#   'title': 'Learning Embeddings from Scientific Corpora using Lexical, Grammatical and Semantic Information',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '1401950156', 'name': 'Andres Garcia-Silva'},
#    {'authorId': '2213589', 'name': 'R. Denaux'},
#    {'authorId': '2420472', 'name': 'José Manuél Gómez-Pérez'}]},
#  {'paperId': 'e0aaff524db88a3b89d2a736aa297081f13af0c8',
#   'title': 'A Visualization Tool for Scholarly Data',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2054326700', 'name': 'M. Salinas'},
#    {'authorId': '1754017', 'name': 'D. Giorgi'},
#    {'authorId': '1729580', 'name': 'F. Ponchio'},
#    {'authorId': '1738697', 'name': 'Paolo Cignoni'}]},
#  {'paperId': '58f1e659b9dedeb7704e736aebaf6f6e245559fe',
#   'title': 'Fair ranking in academic search - Notebook for the TREC 2019 Fair Ranking Track',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '41018503', 'name': 'Malte Bonart'}]},
#  {'paperId': '89ce63af706dcbda6c4c8ae3012d66d00bfced18',
#   'title': 'University of Glasgow Terrier Team and Naver Labs Europe at TREC 2019 Fair Ranking Track',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '38657905', 'name': 'Graham Mcdonald'},
#    {'authorId': '1698205', 'name': 'I. Ounis'},
#    {'authorId': '145434248', 'name': 'Craig Macdonald'},
#    {'authorId': '2955690', 'name': 'Thibaut Thonet'},
#    {'authorId': '2822140', 'name': 'J. Renders'}]},
#  {'paperId': '18c8348008226d8a5438734da35ad76e3c3f640c',
#   'title': 'Story Generation From Knowledge Graphs',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2122316152', 'name': 'Patrick Saad'}]},
#  {'paperId': '103c127a86e6ef2df41430cffddcfe260505bfaf',
#   'title': 'Systematic analysis of testing-related publications concerning comparability and reproducibility',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '31642236', 'name': 'A. Solomonik'}]},
#  {'paperId': 'd95c203e194a29825e0cd635abd87d1030e776f9',
#   'title': 'Scalable, Semi-Supervised Extraction of Structured Information from Scientific Literature',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2052958270', 'name': 'Kritika Agrawal'},
#    {'authorId': '2139180207', 'name': 'Aakash Mittal'},
#    {'authorId': '1787044', 'name': 'Vikram Pudi'}]},
#  {'paperId': 'a97a18b630032b42c1a1c19db64f3fbf09a1c30b',
#   'title': 'Knowledge Graph : Towards Machine Actionability in Scholarly Communication',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '31187184', 'name': 'M. Y. Jaradeh'},
#    {'authorId': '2227190513', 'name': 'Sören'},
#    {'authorId': '2227175066', 'name': 'Auer'},
#    {'authorId': '51065382', 'name': 'Viktor Kovtun'},
#    {'authorId': '1789682566', 'name': 'J. D’Souza'},
#    {'authorId': '153237136', 'name': 'M. Stocker'}]},
#  {'paperId': '2fcbe1e3692b4f5faad41926b781f802f0c1be12',
#   'title': 'Detecting the Landscapes and Hotspots of Scientometrics : A Full-Text Citation Analysis based on Semantic Technology',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2114138334', 'name': 'Li Zeng'},
#    {'authorId': '46947822', 'name': 'Zili Li'},
#    {'authorId': '2116933621', 'name': 'Zhao Zhao'},
#    {'authorId': '13178470', 'name': 'Meixin Mao'}]},
#  {'paperId': '0b32918213f6d18c1bc83585a14cfbc6b9039a16',
#   'title': 'ИССЛЕДОВАТЕЛЬСКИЙ ПОИСК НАУЧНЫХ СТАТЕЙ',
#   'isOpenAccess': True,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '84588011', 'name': 'Ярослав Недумов'},
#    {'authorId': '145306398', 'name': 'Сергей Дмитриевич Кузнецов'}]},
#  {'paperId': None,
#   'title': 'DOES THE INFORMATION-SEEKING BEHAVIOR OF SCIENTISTS CORRESPOND TO EXPLORATORY SEARCH ?',
#   'isOpenAccess': None,
#   'openAccessPdf': None,
#   'authors': []},
#  {'paperId': '463e73debcc2c8d4ee3e79e60be0d9b75e59fc84',
#   'title': 'Gender-Fair (Machine) Translation',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2184245750', 'name': 'Manuel Lardelli'},
#    {'authorId': '2274975520', 'name': 'Dagmar Gromann'}]},
#  {'paperId': '22e57a57f113852cba770f20ee87cbbb01b27111',
#   'title': 'The changing landscape of text mining - a review of approaches for ecology and evolution',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '8035829', 'name': 'M. Farrell'},
#    {'authorId': '72336044', 'name': 'N. Guillarme'},
#    {'authorId': '3715852', 'name': 'Liam Brierley'},
#    {'authorId': '2289107754', 'name': 'Bronwen Hunter'},
#    {'authorId': '2132547664', 'name': 'Daan Scheepens'},
#    {'authorId': '2289109059', 'name': 'Anna Willoughby'},
#    {'authorId': '2289109326', 'name': 'Andrew Yates'},
#    {'authorId': '3383502', 'name': 'N. Mideo'}]},
#  {'paperId': '1dea91742e80f2f3cb2a42224ec300ceac359f4a',
#   'title': 'The Development and Deployment of Large Language Models in Medicine',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2265945051', 'name': 'Hongjian Zhou'},
#    {'authorId': '2218961178', 'name': 'Fenglin Liu'},
#    {'authorId': '2265754434', 'name': 'Boyang Gu'},
#    {'authorId': '2265783554', 'name': 'Xinyu Zou'},
#    {'authorId': '2266440308', 'name': 'Jinfa Huang'},
#    {'authorId': '2310773409', 'name': 'Jinge Wu'},
#    {'authorId': '2265924823', 'name': 'Yiru Li'},
#    {'authorId': '2265803524', 'name': 'Sam S. Chen'},
#    {'authorId': '1800462890', 'name': 'Peilin Zhou'},
#    {'authorId': '2218869839', 'name': 'Junling Liu'},
#    {'authorId': '2299327336', 'name': 'Yining Hua'},
#    {'authorId': '2265754569', 'name': 'Chengfeng Mao'},
#    {'authorId': '2269138319', 'name': 'Chenyu You'},
#    {'authorId': '2269413539', 'name': 'Xian Wu'},
#    {'authorId': '2237585282', 'name': 'Yefeng Zheng'},
#    {'authorId': '7887815', 'name': 'Lei A. Clifton'},
#    {'authorId': '2266043640', 'name': 'Zheng Li'},
#    {'authorId': '2273966071', 'name': 'Jiebo Luo'},
#    {'authorId': '2273678614', 'name': 'David A. Clifton'}]},
#  {'paperId': '4a4f4277936b35ef033ab64c57f7cc848ca90aae',
#   'title': 'Leveraging multiple control codes for aspect-controllable related paper recommendation',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2186557380', 'name': 'Kehan Long'},
#    {'authorId': '2145340498', 'name': 'Shasha Li'},
#    {'authorId': '1762106', 'name': 'Jintao Tang'},
#    {'authorId': '2257363292', 'name': 'Ting Wang'}]},
#  {'paperId': '38503f99464f115a3cb05dfc4e96e7fe85454188',
#   'title': 'AUC Knowledge Fountain AUC Knowledge Fountain',
#   'isOpenAccess': False,
#   'openAccessPdf': None,
#   'authors': [{'authorId': '2324457607', 'name': 'Mohamed Mohsen'},
#    {'authorId': '2286042428', 'name': 'Contents'}]}]
#                                       paperId  \
# 0    db4e8d662dbe80f3ddf78e69b1c1053500894d25
# 1    50a3f0dd12114fb2ca90a5511a6325524c3f6013
# 2    5eafc35cedbb28b033009947ca73b40007b2b407
# 3    4772df95a893061e0fedc9a09c56f95d8926fb9d
# 4    036fd8b92722023742dc7fceb19a2ea1d56828de
# ..                                        ...
# 374  463e73debcc2c8d4ee3e79e60be0d9b75e59fc84
# 375  22e57a57f113852cba770f20ee87cbbb01b27111
# 376  1dea91742e80f2f3cb2a42224ec300ceac359f4a
# 377  4a4f4277936b35ef033ab64c57f7cc848ca90aae
# 378  38503f99464f115a3cb05dfc4e96e7fe85454188
#
#                                                  title isOpenAccess  \
# 0    A Database of Stress-Strain Properties Auto-ge...        False
# 1    Evaluating GPT and BERT models for protein–pro...         True
# 2    Paper Copilot: A Self-Evolving and Efficient L...        False
# 3    Temporal Graph Neural Network-Powered Paper Re...        False
# 4    Harvesting Textual and Structured Data from th...        False
# ..                                                 ...          ...
# 374                  Gender-Fair (Machine) Translation        False
# 375  The changing landscape of text mining - a revi...        False
# 376  The Development and Deployment of Large Langua...        False
# 377  Leveraging multiple control codes for aspect-c...        False
# 378      AUC Knowledge Fountain AUC Knowledge Fountain        False
#
#     openAccessPdf                                            authors
# 0            None  [{'authorId': '2193266278', 'name': 'Pankaj Ku...
# 1            None  [{'authorId': '35668704', 'name': 'Hasin Rehan...
# 2            None  [{'authorId': '2301577462', 'name': 'Guanyu Li...
# 3            None  [{'authorId': '2284397773', 'name': 'Junhao Sh...
# 4            None  [{'authorId': '2313732350', 'name': 'Francis K...
# ..            ...                                                ...
# 374          None  [{'authorId': '2184245750', 'name': 'Manuel La...
# 375          None  [{'authorId': '8035829', 'name': 'M. Farrell'}...
# 376          None  [{'authorId': '2265945051', 'name': 'Hongjian ...
# 377          None  [{'authorId': '2186557380', 'name': 'Kehan Lon...
# 378          None  [{'authorId': '2324457607', 'name': 'Mohamed M...
#
# [379 rows x 5 columns]

# %%
citation_df.dropna(subset=['openAccessPdf']).head(5)
# Out:
#                                      paperId  \
# 11  e11c67919830bb0a29a86b05936d467227accc81
# 12  c5a528afd98274902b4987b887f19ecd282ca8bd
# 13  ce2beb2ad9efa56abdc59f4c613bda52cc11803c
# 16  1571d11e5c22d0bdefce3f6ffa333f040a2e409d
# 17  61313651e06abb093dfa3fd4430a1f5b146d5b35
#
#                                                 title isOpenAccess  \
# 11  openalexR: An R-Tool for Collecting Bibliometr...         True
# 12  BioBBC: a multi-feature model that enhances th...         True
# 13  Surveying biomedical relation extraction: a cr...         True
# 16  MetaTron: advancing biomedical annotation empo...         True
# 17  The geography of eco-innovations and sustainab...         True
#
#                                         openAccessPdf  \
# 11  {'url': 'https://journal.r-project.org/article...
# 12  {'url': 'https://www.nature.com/articles/s4159...
# 13  {'url': 'https://academic.oup.com/bib/article-...
# 16  {'url': 'https://bmcbioinformatics.biomedcentr...
# 17  {'url': 'https://www.degruyter.com/document/do...
#
#                                               authors
# 11  [{'authorId': '2248919040', 'name': 'Massimo A...
# 12  [{'authorId': '1753416672', 'name': 'Hind Alam...
# 13  [{'authorId': '47451980', 'name': 'Ming-Siang ...
# 16  [{'authorId': '2051750606', 'name': 'Ornella I...
# 17  [{'authorId': '2085072010', 'name': 'Hendrik H...

# %% [markdown]
# # Download Papers

# %%
def get_paper_forPdf(session: requests.Session, paper_id: str, fields: str = 'paperId,title', **kwargs) -> dict:
    params = {
        'fields': fields,
        **kwargs,
    }
    headers = {
        'X-API-KEY': S2_API_KEY,
    }

    with session.get(f'https://api.semanticscholar.org/graph/v1/paper/{paper_id}', params=params, headers=headers) as response:
        response.raise_for_status()
        print(response.json())
        return response.json()

def download_pdf(session: requests.Session, url: str, path: str, user_agent: str = 'requests/2.0.0'):
    # send a user-agent to avoid server error
    headers = {
        'user-agent': user_agent,
    }

    # stream the response to avoid downloading the entire file into memory
    with session.get(url, headers=headers, stream=True, verify=False) as response:
        # check if the request was successful
        response.raise_for_status()

        with open(path, 'wb') as f:
            # write the response to the file, chunk_size bytes at a time
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)


def download_paper(session: requests.Session, paper_id: str, directory: str = 'papers', user_agent: str = 'requests/2.0.0') -> Union[str, None]:
    paper = get_paper_forPdf(session, paper_id, fields='paperId,isOpenAccess,openAccessPdf')

    # check if the paper is open access
    if not paper['isOpenAccess']:
        print(f'Paper {paper_id} is not open access.')
        return None

    if paper['openAccessPdf'] is None:
        print(f'Paper {paper_id} does not have an open access pdf.')
        return None

    paperId: str = paper['paperId']
    pdf_url: str = paper['openAccessPdf']['url']
    pdf_path = os.path.join(directory, f'{paperId}.pdf')

    # create the directory if it doesn't exist
    os.makedirs(directory, exist_ok=True)

    # check if the pdf has already been downloaded
    if not os.path.exists(pdf_path):
        download_pdf(session, pdf_url, pdf_path, user_agent=user_agent)

    return pdf_path


def download_papers(paper_ids: list[str], directory: str = 'papers', user_agent: str = 'requests/2.0.0') -> Generator[tuple[str, Union[str, None, Exception]], None, None]:
    # use a session to reuse the same TCP connection
    with requests.Session() as session:
        for paper_id in paper_ids:
            try:
                yield paper_id, download_paper(session, paper_id, directory=directory, user_agent=user_agent)
            except Exception as e:
                yield paper_id, e


paperID = 'd449ec41cd3222f9f8b325adfacc8f4b9e7b95d3'
session = requests.Session()
print(download_paper(session=session, paper_id=paperID))
# Out:
# {'paperId': 'd449ec41cd3222f9f8b325adfacc8f4b9e7b95d3', 'isOpenAccess': True, 'openAccessPdf': {'url': 'https://www.aclweb.org/anthology/W18-2306.pdf', 'status': 'HYBRID'}}
# papers/d449ec41cd3222f9f8b325adfacc8f4b9e7b95d3.pdf

# %%
# 读取 URLs
urlDf = pd.read_csv('/Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/citationURLs.csv')
urls = urlDf['url'].tolist()
display(urlDf)

# 下载 PDF 的函数
def download_papers_from_urls(urls: list[str], directory: str, user_agent: str = 'requests/2.0.0', timeout: int = 10) -> Generator[tuple[str, Union[str, None, Exception]], None, None]:
    # 检查保存目录是否存在，不存在则创建
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # 使用 Session 复用 TCP 连接
    with requests.Session() as session:
        session.headers.update({'user-agent': user_agent})  # 设置 User-Agent
        for idx, url in enumerate(urls, 1):
            try:
                # 自动生成文件名
                filename = os.path.join(directory, f"paper_{idx}.pdf")
                print(f"Downloading {url} to {filename}...")
                download_pdf(session, url, filename, timeout)
                yield (url, filename, None)  # 返回成功信息
            except requests.exceptions.Timeout:
                print(f"Timeout occurred while downloading {url}. Skipping...")
                yield (url, None, "Timeout")  # 返回超时信息
            except Exception as e:
                print(f"Failed to download {url}: {e}")
                yield (url, None, e)  # 返回其他错误信息

# 下载单个 PDF 的函数
def download_pdf(session: requests.Session, url: str, filepath: str, timeout: int):
    # 使用流式响应避免将整个文件加载到内存中
    with session.get(url, stream=True, verify=True, timeout=timeout) as response:
        response.raise_for_status()  # 检查请求是否成功
        with open(filepath, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):  # 分块写入文件
                f.write(chunk)

# 执行下载
for result in download_papers_from_urls(urls, directory='/Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/', timeout=10):  # 设置超时时间为 10 秒
    url, filepath, error = result
    if error:
        print(f"Error downloading {url}: {error}")
    else:
        print(f"Downloaded {url} to {filepath}")
# Out:
#     Unnamed: 0                                                url  status
# 0            0                     https://doi.org/10.3386/w32540     NaN
# 1            1  https://dl.acm.org/doi/pdf/10.1145/3677052.369...     NaN
# 2            2  https://www.econstor.eu/bitstream/10419/282537...     NaN
# 3            3                   https://arxiv.org/pdf/2403.06150     NaN
# 4            4  https://www.mdpi.com/2227-7099/12/3/59/pdf?ver...     NaN
# ..         ...                                                ...     ...
# 83          83                    http://arxiv.org/pdf/2205.04619     NaN
# 84          84                   https://arxiv.org/pdf/2208.06308     NaN
# 85          85                   https://arxiv.org/pdf/2212.03152     NaN
# 86          86  https://www.econstor.eu/bitstream/10419/246229...     NaN
# 87          87  https://www.coll.mpg.de/pdf_dat/2021_11online.pdf     NaN
#
# [88 rows x 3 columns]
# Downloading https://doi.org/10.3386/w32540 to /Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/paper_1.pdf...
# Downloaded https://doi.org/10.3386/w32540 to /Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/paper_1.pdf
# Downloading https://dl.acm.org/doi/pdf/10.1145/3677052.3698621 to /Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/paper_2.pdf...
# Downloaded https://dl.acm.org/doi/pdf/10.1145/3677052.3698621 to /Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/paper_2.pdf
# Downloading https://www.econstor.eu/bitstream/10419/282537/1/cesifo1_wp10849.pdf to /Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/paper_3.pdf...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 44
#      41                 f.write(chunk)
#      43 # 执行下载
# ---> 44 for result in download_papers_from_urls(urls, directory='/Users/Stansfield/Library/CloudStorage/OneDrive-sjtu.edu.cn/24春季课程/深度学习/深度学习大作业/papers/', timeout=10):  # 设置超时时间为 10 秒
#      45     url, filepath, error = result
#      46     if error:
#
# Cell In[26], line 25, in download_papers_from_urls(urls, directory, user_agent, timeout)
#      23     filename = os.path.join(directory, f"paper_{idx}.pdf")
#      24     print(f"Downloading {url} to {filename}...")
# ---> 25     download_pdf(session, url, filename, timeout)
#      26     yield (url, filename, None)  # 返回成功信息
#      27 except requests.exceptions.Timeout:
#
# Cell In[26], line 40, in download_pdf(session, url, filepath, timeout)
#      38 response.raise_for_status()  # 检查请求是否成功
#      39 with open(filepath, 'wb') as f:
# ---> 40     for chunk in response.iter_content(chunk_size=8192):  # 分块写入文件
#      41         f.write(chunk)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/response.py:831, in HTTPResponse.read_chunked(self, amt, decode_content)
#     829 if self.chunk_left == 0:
#     830     break
# --> 831 chunk = self._handle_chunk(amt)
#     832 decoded = self._decode(
#     833     chunk, decode_content=decode_content, flush_decoder=False
#     834 )
#     835 if decoded:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/response.py:784, in HTTPResponse._handle_chunk(self, amt)
#     782     returned_chunk = value
#     783 else:  # amt > self.chunk_left
# --> 784     returned_chunk = self._fp._safe_read(self.chunk_left)
#     785     self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     786     self.chunk_left = None
#
# File ~/anaconda3/lib/python3.10/http/client.py:631, in HTTPResponse._safe_read(self, amt)
#     624 def _safe_read(self, amt):
#     625     """Read the number of bytes requested.
#     626
#     627     This function should be used when <amt> bytes "should" be present for
#     628     reading. If the bytes are truly not available (due to EOF), then the
#     629     IncompleteRead exception can be used to detect the problem.
#     630     """
# --> 631     data = self.fp.read(amt)
#     632     if len(data) < amt:
#     633         raise IncompleteRead(data, amt-len(data))
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Get Comments

# %%
# read pdf
import fitz

def read_pdf(pdf_path: str) -> str:
    with fitz.open(pdf_path) as pdf:
        text = ''
        for page in pdf:
            text += page.get_text()
        return text

read_pdf('papers/d449ec41cd3222f9f8b325adfacc8f4b9e7b95d3.pdf')
# Out:
# 'Proceedings of the BioNLP 2018 workshop, pages 47–55\nMelbourne, Australia, July 19, 2018. c⃝2018 Association for Computational Linguistics\n47\nOntology Alignment in the Biomedical Domain\nUsing Entity Deﬁnitions and Context\nLucy Lu Wang†, Chandra Bhagavatula, Mark Neumann,\nKyle Lo, Chris Wilhelm, and Waleed Ammar\nAllen Institute for Artiﬁcial Intelligence\n†Department of Biomedical Informatics and Medical Education, University of Washington\nSeattle, Washington, USA\nlucylw@uw.edu\nAbstract\nOntology alignment is the task of identi-\nfying semantically equivalent entities from\ntwo given ontologies. Different ontologies\nhave different representations of the same\nentity, resulting in a need to de-duplicate\nentities when merging ontologies. We pro-\npose a method for enriching entities in an\nontology with external deﬁnition and con-\ntext information, and use this additional\ninformation for ontology alignment. We\ndevelop a neural architecture capable of\nencoding the additional information when\navailable, and show that the addition of\nexternal data results in an F1-score of\n0.69 on the Ontology Alignment Evalua-\ntion Initiative (OAEI) largebio SNOMED-\nNCI subtask, comparable with the entity-\nlevel matchers in a SOTA system.\n1\nIntroduction\nOntologies are used to ground lexical items in var-\nious NLP tasks including entity linking, question\nanswering, semantic parsing and information re-\ntrieval.1\nIn biomedicine, an abundance of on-\ntologies (e.g., MeSH, Gene Ontology) has been\ndeveloped for different purposes. Each ontology\ndescribes a large number of concepts in health-\ncare, public health or biology, enabling the use of\nontology-based NLP methods in biomedical appli-\ncations. However, since these ontologies are typ-\nically curated independently by different groups,\nmany important concepts are represented inconsis-\ntently across ontologies (e.g., “Myoclonic Epilep-\nsies, Progressive” in MeSH is a broader concept\n1Ontological resources include ontologies, knowledgebases,\nterminologies, and controlled vocabularies. In the rest of this\npaper, we refer to all of these with the term ‘ontology’ for\nconsistency.\nthat includes “Dentatorubral-pallidoluysian atro-\nphy” from OMIM).\nThis poses a challenge for bioNLP applica-\ntions where multiple ontologies are needed for\ngrounding, but each concept must be repre-\nsented by only one entity.\nFor instance, in\nwww.semanticscholar.org, scientiﬁc pub-\nlications related to carpal tunnel syndrome are\nlinked to one of multiple entities derived from\nUMLS terminologies representing the same con-\ncept,2 making it hard to ﬁnd all relevant papers on\nthis topic. To address this challenge, we need to\nautomatically map semantically equivalent entities\nfrom one ontology to another. This task is referred\nto as ontology alignment or ontology matching.\nSeveral methods have been applied to ontol-\nogy alignment, including rule-based and statisti-\ncal matchers. Existing matchers rely on entity fea-\ntures such as names, synonyms, as well as rela-\ntionships to other entities (Shvaiko and Euzenat,\n2013; Otero-Cerdeira et al., 2015). However, it\nis unclear how to leverage the natural language\ntext associated with entities to improve predic-\ntions. We address this limitation by incorporating\ntwo types of natural language information (deﬁni-\ntions and textual contexts) in a supervised learning\nframework for ontology alignment. Since the def-\ninition and textual contexts of an entity often pro-\nvide complementary information about the entity’s\nmeaning, we hypothesize that incorporating them\nwill improve model predictions. We also discuss\nhow to automatically derive labeled data for train-\ning the model by leveraging existing resources. In\nparticular, we make the following contributions:\n• We propose a novel neural architecture for on-\ntology alignment and show how to effectively\n2See\nhttps://www.semanticscholar.org/\ntopic/Carpal-tunnel-syndrom ...
